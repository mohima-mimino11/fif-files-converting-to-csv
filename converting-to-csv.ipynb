# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/preproccesed-dataset/audio-channel-resting14/kaggle/working/preprocessed_audio_output_directory14/08_mfccs.npy
# /kaggle/input/preproccesed-dataset/audio-channel-resting14/kaggle/working/preprocessed_audio_output_directory14/16_mfccs.npy
# /kaggle/input/preproccesed-dataset/audio-channel-resting14/kaggle/working/preprocessed_audio_output_directory14/24_mfccs.npy
# /kaggle/input/preproccesed-dataset/audio-channel-resting14/kaggle/working/preprocessed_audio_output_directory14/05_mfccs.npy
# /kaggle/input/preproccesed-dataset/audio-channel-resting14/kaggle/working/preprocessed_audio_output_directory14/15_mfccs.npy
# /kaggle/input/preproccesed-dataset/audio-channel-resting14/kaggle/working/preprocessed_audio_output_directory14/06_mfccs.npy
# /kaggle/input/preproccesed-dataset/audio-channel-resting14/kaggle/working/preprocessed_audio_output_directory14/25_mfccs.npy
# ...

# %% [raw]
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load
#
# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
#
# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
#
# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))
#
# # You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# # You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import mne
import numpy as np
import pandas as pd
import os
import warnings

# Directories
input_dirs = [
    '/kaggle/input/preproccesed-dataset/128-channel-ERP/kaggle/working/preprocessed_raw_output_directory', 
    '/kaggle/input/preproccesed-dataset/3-channel-resting/kaggle/working',
    '/kaggle/input/preproccesed-dataset/128-channel-resting(2.0)/kaggle/working/preprocessed_mat_output_directory',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting10/kaggle/working/preprocessed_audio_output_directory10'
]
output_dir = '/kaggle/working/csv_files'
os.makedirs(output_dir, exist_ok=True) 

# Function to convert .fif files to CSV
def convert_fif_to_csv(file_path, output_dir):
    with warnings.catch_warnings():
        warnings.simplefilter("ignore", RuntimeWarning)
        try:
            epochs = mne.read_epochs(file_path, verbose=False)
            if len(epochs) == 0:
                print(f"No data in file {file_path}, skipping.")
                return
            df_epochs = epochs.to_data_frame()
            csv_file_path = os.path.join(output_dir, os.path.basename(file_path).replace('-epo.fif', '.csv'))
            df_epochs.to_csv(csv_file_path, index=False)
        except Exception as e:
            print(f"Error processing {file_path}: {e}")

# Function to convert .npy files to CSV
def convert_npy_to_csv(file_path, output_dir):
    try:
        data = np.load(file_path)
        df_mfccs = pd.DataFrame(data)
        csv_file_path = os.path.join(output_dir, os.path.basename(file_path).replace('.mfccs.npy', '.csv'))
        df_mfccs.to_csv(csv_file_path, index=False)
    except Exception as e:
        print(f"Error processing {file_path}: {e}")

# Iterate through each input directory
for dir in input_dirs:
    for file in os.listdir(dir):
        file_path = os.path.join(dir, file)
        if file.endswith('-epo.fif'):
            convert_fif_to_csv(file_path, output_dir)
        elif file.endswith('.mfccs.npy'):
            convert_npy_to_csv(file_path, output_dir)
# Out:
# No data in file /kaggle/input/preproccesed-dataset/128-channel-ERP/kaggle/working/preprocessed_raw_output_directory/02030021erp 20160105 1204-epo.fif, skipping.
# No data in file /kaggle/input/preproccesed-dataset/128-channel-ERP/kaggle/working/preprocessed_raw_output_directory/02010012erp 20150626 1059-epo.fif, skipping.
# No data in file /kaggle/input/preproccesed-dataset/128-channel-ERP/kaggle/working/preprocessed_raw_output_directory/02030006 20151103 1801-epo.fif, skipping.
# No data in file /kaggle/input/preproccesed-dataset/128-channel-ERP/kaggle/working/preprocessed_raw_output_directory/02010023erp 20150729 1955-epo.fif, skipping.
# No data in file /kaggle/input/preproccesed-dataset/128-channel-ERP/kaggle/working/preprocessed_raw_output_directory/02020022_erp 20150707 1515-epo.fif, skipping.
# No data in file /kaggle/input/preproccesed-dataset/128-channel-ERP/kaggle/working/preprocessed_raw_output_directory/02020021_erp 20150707 1751-epo.fif, skipping.
# ...

# %%
import mne
import numpy as np
import pandas as pd
import os
import warnings

# Directories
input_dirs = ['/kaggle/input/preproccesed-dataset/audio-channel-resting/kaggle/working/preprocessed_audio_output_directory',
              '/kaggle/input/preproccesed-dataset/audio-channel-resting11/kaggle/working/preprocessed_audio_output_directory11',
              '/kaggle/input/preproccesed-dataset/audio-channel-resting10/kaggle/working/preprocessed_audio_output_directory10',
              '/kaggle/input/preproccesed-dataset/audio-channel-resting12/kaggle/working/preprocessed_audio_output_directory12',
              '/kaggle/input/preproccesed-dataset/audio-channel-resting13/kaggle/working/preprocessed_audio_output_directory13',
              '/kaggle/input/preproccesed-dataset/audio-channel-resting14/kaggle/working/preprocessed_audio_output_directory14',
              '/kaggle/input/preproccesed-dataset/audio-channel-resting15/kaggle/working/preprocessed_audio_output_directory15',
              '/kaggle/input/preproccesed-dataset/audio-channel-resting16/kaggle/working/preprocessed_audio_output_directory16',
              '/kaggle/input/preproccesed-dataset/audio-channel-resting18/kaggle/working/preprocessed_audio_output_directory18',
              '/kaggle/input/preproccesed-dataset/audio-channel-resting19/kaggle/working/preprocessed_audio_output_directory19',
              '/kaggle/input/preproccesed-dataset/audio-channel-resting2/kaggle/working/preprocessed_audio_output_directory2',
              '/kaggle/input/preproccesed-dataset/audio-channel-resting21/kaggle/working/preprocessed_audio_output_directory21',
              '/kaggle/input/preproccesed-dataset/audio-channel-resting22/kaggle/working/preprocessed_audio_output_directory22',
              '/kaggle/input/preproccesed-dataset/audio-channel-resting23/kaggle/working/preprocessed_audio_output_directory23',
              '/kaggle/input/preproccesed-dataset/audio-channel-resting25/kaggle/working/preprocessed_audio_output_directory25',
              '/kaggle/input/preproccesed-dataset/audio-channel-resting26/kaggle/working/preprocessed_audio_output_directory26',
              '/kaggle/input/preproccesed-dataset/audio-channel-resting27/kaggle/working/preprocessed_audio_output_directory27',
              '/kaggle/input/preproccesed-dataset/audio-channel-resting3/kaggle/working/preprocessed_audio_output_directory3',
              '/kaggle/input/preproccesed-dataset/audio-channel-resting3.1/kaggle/working/preprocessed_audio_output_directory3.1',
              '/kaggle/input/preproccesed-dataset/audio-channel-resting3.10/kaggle/working/preprocessed_audio_output_directory3.10',
              '/kaggle/input/preproccesed-dataset/audio-channel-resting3.14/kaggle/working/preprocessed_audio_output_directory3.14',
              '/kaggle/input/preproccesed-dataset/audio-channel-resting3.15/kaggle/working/preprocessed_audio_output_directory3.15',
              '/kaggle/input/preproccesed-dataset/audio-channel-resting3.16/kaggle/working/preprocessed_audio_output_directory3.16',
              '/kaggle/input/preproccesed-dataset/audio-channel-resting3.17/kaggle/working/preprocessed_audio_output_directory3.17',
              '/kaggle/input/preproccesed-dataset/audio-channel-resting3.2/kaggle/working/preprocessed_audio_output_directory3.2',
              '/kaggle/input/preproccesed-dataset/audio-channel-resting3.4/kaggle/working/preprocessed_audio_output_directory3.4',
              '/kaggle/input/preproccesed-dataset/audio-channel-resting3.5/kaggle/working/preprocessed_audio_output_directory3.5',
              '/kaggle/input/preproccesed-dataset/audio-channel-resting3.6/kaggle/working/preprocessed_audio_output_directory3.6',
              '/kaggle/input/preproccesed-dataset/audio-channel-resting3.7/kaggle/working/preprocessed_audio_output_directory3.7',
              '/kaggle/input/preproccesed-dataset/audio-channel-resting3.8/kaggle/working/preprocessed_audio_output_directory3.8',
              '/kaggle/input/preproccesed-dataset/audio-channel-resting3.9/kaggle/working/preprocessed_audio_output_directory3.9',
              '/kaggle/input/preproccesed-dataset/audio-channel-resting4/kaggle/working/preprocessed_audio_output_directory4',
              '/kaggle/input/preproccesed-dataset/audio-channel-resting5/kaggle/working/preprocessed_audio_output_directory5',
              '/kaggle/input/preproccesed-dataset/audio-channel-resting6/kaggle/working/preprocessed_audio_output_directory6',
              '/kaggle/input/preproccesed-dataset/audio-channel-resting8/kaggle/working/preprocessed_audio_output_directory8',
              '/kaggle/input/preproccesed-dataset/audio-channel-resting9/kaggle/working/preprocessed_audio_output_directory9']
output_dir = '/kaggle/working/audio_csv_files'
os.makedirs(output_dir, exist_ok=True) 

# Function to convert .fif files to CSV
# def convert_fif_to_csv(file_path, output_dir):
#     with warnings.catch_warnings():
#         warnings.simplefilter("ignore", RuntimeWarning)
#         try:
#             epochs = mne.read_epochs(file_path, verbose=False)
#             if len(epochs) == 0:
#                 print(f"No data in file {file_path}, skipping.")
#                 return
#             df_epochs = epochs.to_data_frame()
#             csv_file_path = os.path.join(output_dir, os.path.basename(file_path).replace('-epo.fif', '.csv'))
#             df_epochs.to_csv(csv_file_path, index=False)
#         except Exception as e:
#             print(f"Error processing {file_path}: {e}")

# Function to convert .npy files to CSV
def convert_npy_to_csv(file_path, output_dir):
    try:
        data = np.load(file_path)
        df_mfccs = pd.DataFrame(data)
        csv_file_path = os.path.join(output_dir, os.path.basename(file_path).replace('_mfccs.npy', '.csv'))
        df_mfccs.to_csv(csv_file_path, index=False)
    except Exception as e:
        print(f"Error processing {file_path}: {e}")

# Iterate through each input directory
for dir in input_dirs:
    for file in os.listdir(dir):
        file_path = os.path.join(dir, file)
#         if file.endswith('-epo.fif'):
#             convert_fif_to_csv(file_path, output_dir)
        if file.endswith('_mfccs.npy'):
            convert_npy_to_csv(file_path, output_dir)
# Out:
# Error processing /kaggle/input/preproccesed-dataset/audio-channel-resting/kaggle/working/preprocessed_audio_output_directory/08_mfccs.npy: Object arrays cannot be loaded when allow_pickle=False
# Error processing /kaggle/input/preproccesed-dataset/audio-channel-resting/kaggle/working/preprocessed_audio_output_directory/16_mfccs.npy: Object arrays cannot be loaded when allow_pickle=False
# Error processing /kaggle/input/preproccesed-dataset/audio-channel-resting/kaggle/working/preprocessed_audio_output_directory/24_mfccs.npy: Object arrays cannot be loaded when allow_pickle=False
# Error processing /kaggle/input/preproccesed-dataset/audio-channel-resting/kaggle/working/preprocessed_audio_output_directory/05_mfccs.npy: Object arrays cannot be loaded when allow_pickle=False
# Error processing /kaggle/input/preproccesed-dataset/audio-channel-resting/kaggle/working/preprocessed_audio_output_directory/15_mfccs.npy: Object arrays cannot be loaded when allow_pickle=False
# ...

# %%
import numpy as np
import pandas as pd
import os
import warnings

# Directories
input_dirs = [
    '/kaggle/input/preproccesed-dataset/audio-channel-resting/kaggle/working/preprocessed_audio_output_directory',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting11/kaggle/working/preprocessed_audio_output_directory11',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting10/kaggle/working/preprocessed_audio_output_directory10',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting12/kaggle/working/preprocessed_audio_output_directory12',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting13/kaggle/working/preprocessed_audio_output_directory13',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting14/kaggle/working/preprocessed_audio_output_directory14',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting15/kaggle/working/preprocessed_audio_output_directory15',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting16/kaggle/working/preprocessed_audio_output_directory16',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting18/kaggle/working/preprocessed_audio_output_directory18',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting19/kaggle/working/preprocessed_audio_output_directory19',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting2/kaggle/working/preprocessed_audio_output_directory2',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting21/kaggle/working/preprocessed_audio_output_directory21',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting22/kaggle/working/preprocessed_audio_output_directory22',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting23/kaggle/working/preprocessed_audio_output_directory23',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting25/kaggle/working/preprocessed_audio_output_directory25',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting26/kaggle/working/preprocessed_audio_output_directory26',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting27/kaggle/working/preprocessed_audio_output_directory27',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3/kaggle/working/preprocessed_audio_output_directory3',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.1/kaggle/working/preprocessed_audio_output_directory3.1',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.10/kaggle/working/preprocessed_audio_output_directory3.10',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.14/kaggle/working/preprocessed_audio_output_directory3.14',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.15/kaggle/working/preprocessed_audio_output_directory3.15',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.16/kaggle/working/preprocessed_audio_output_directory3.16',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.17/kaggle/working/preprocessed_audio_output_directory3.17',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.2/kaggle/working/preprocessed_audio_output_directory3.2',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.4/kaggle/working/preprocessed_audio_output_directory3.4',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.5/kaggle/working/preprocessed_audio_output_directory3.5',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.6/kaggle/working/preprocessed_audio_output_directory3.6',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.7/kaggle/working/preprocessed_audio_output_directory3.7',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.8/kaggle/working/preprocessed_audio_output_directory3.8',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.9/kaggle/working/preprocessed_audio_output_directory3.9',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting4/kaggle/working/preprocessed_audio_output_directory4',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting5/kaggle/working/preprocessed_audio_output_directory5',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting6/kaggle/working/preprocessed_audio_output_directory6',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting8/kaggle/working/preprocessed_audio_output_directory8',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting9/kaggle/working/preprocessed_audio_output_directory9'
]
output_dir = '/kaggle/working/audio_csv_files'
os.makedirs(output_dir, exist_ok=True)

# Function to convert .npy files to CSV
def convert_npy_to_csv(file_path, output_dir):
    try:
        # Load .npy file with allow_pickle=True
        data = np.load(file_path, allow_pickle=True)
        df_mfccs = pd.DataFrame(data)
        csv_file_path = os.path.join(output_dir, os.path.basename(file_path).replace('_mfccs.npy', '.csv'))
        df_mfccs.to_csv(csv_file_path, index=False)
    except Exception as e:
        print(f"Error processing {file_path}: {e}")

# Iterate through each input directory
for dir in input_dirs:
    for file in os.listdir(dir):
        file_path = os.path.join(dir, file)
        if file.endswith('_mfccs.npy'):
            convert_npy_to_csv(file_path, output_dir)
# Out:
# Error processing /kaggle/input/preproccesed-dataset/audio-channel-resting/kaggle/working/preprocessed_audio_output_directory/08_mfccs.npy: Must pass 2-d input. shape=()
# Error processing /kaggle/input/preproccesed-dataset/audio-channel-resting/kaggle/working/preprocessed_audio_output_directory/16_mfccs.npy: Must pass 2-d input. shape=()
# Error processing /kaggle/input/preproccesed-dataset/audio-channel-resting/kaggle/working/preprocessed_audio_output_directory/24_mfccs.npy: Must pass 2-d input. shape=()
# Error processing /kaggle/input/preproccesed-dataset/audio-channel-resting/kaggle/working/preprocessed_audio_output_directory/05_mfccs.npy: Must pass 2-d input. shape=()
# Error processing /kaggle/input/preproccesed-dataset/audio-channel-resting/kaggle/working/preprocessed_audio_output_directory/15_mfccs.npy: Must pass 2-d input. shape=()
# ...

# %%
import numpy as np
import pandas as pd
import os

# Directories
input_dirs = [
    '/kaggle/input/preproccesed-dataset/audio-channel-resting/kaggle/working/preprocessed_audio_output_directory',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting11/kaggle/working/preprocessed_audio_output_directory11',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting10/kaggle/working/preprocessed_audio_output_directory10',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting12/kaggle/working/preprocessed_audio_output_directory12',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting13/kaggle/working/preprocessed_audio_output_directory13',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting14/kaggle/working/preprocessed_audio_output_directory14',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting15/kaggle/working/preprocessed_audio_output_directory15',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting16/kaggle/working/preprocessed_audio_output_directory16',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting18/kaggle/working/preprocessed_audio_output_directory18',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting19/kaggle/working/preprocessed_audio_output_directory19',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting2/kaggle/working/preprocessed_audio_output_directory2',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting21/kaggle/working/preprocessed_audio_output_directory21',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting22/kaggle/working/preprocessed_audio_output_directory22',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting23/kaggle/working/preprocessed_audio_output_directory23',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting25/kaggle/working/preprocessed_audio_output_directory25',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting26/kaggle/working/preprocessed_audio_output_directory26',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting27/kaggle/working/preprocessed_audio_output_directory27',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3/kaggle/working/preprocessed_audio_output_directory3',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.1/kaggle/working/preprocessed_audio_output_directory3.1',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.10/kaggle/working/preprocessed_audio_output_directory3.10',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.14/kaggle/working/preprocessed_audio_output_directory3.14',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.15/kaggle/working/preprocessed_audio_output_directory3.15',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.16/kaggle/working/preprocessed_audio_output_directory3.16',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.17/kaggle/working/preprocessed_audio_output_directory3.17',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.2/kaggle/working/preprocessed_audio_output_directory3.2',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.4/kaggle/working/preprocessed_audio_output_directory3.4',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.5/kaggle/working/preprocessed_audio_output_directory3.5',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.6/kaggle/working/preprocessed_audio_output_directory3.6',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.7/kaggle/working/preprocessed_audio_output_directory3.7',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.8/kaggle/working/preprocessed_audio_output_directory3.8',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.9/kaggle/working/preprocessed_audio_output_directory3.9',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting4/kaggle/working/preprocessed_audio_output_directory4',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting5/kaggle/working/preprocessed_audio_output_directory5',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting6/kaggle/working/preprocessed_audio_output_directory6',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting8/kaggle/working/preprocessed_audio_output_directory8',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting9/kaggle/working/preprocessed_audio_output_directory9'
]
output_dir = '/kaggle/working/audio_csv_files'
os.makedirs(output_dir, exist_ok=True)

# Function to convert .npy files to CSV
def convert_npy_to_csv(file_path, output_dir):
    try:
        # Load .npy file with allow_pickle=True
        data = np.load(file_path, allow_pickle=True)
        
        # Check for empty arrays
        if data.shape == ():
            print(f"File {file_path} is empty, skipping.")
            return

        # Check if data is 2D array
        if data.ndim == 2:
            df_mfccs = pd.DataFrame(data)
        # Handle 1D data
        elif data.ndim == 1:
            df_mfccs = pd.DataFrame(data.reshape(-1, 1))
        # Handle other dimensions
        else:
            print(f"Unsupported data shape {data.shape} in file {file_path}, skipping.")
            return
        
        csv_file_path = os.path.join(output_dir, os.path.basename(file_path).replace('_mfccs.npy', '.csv'))
        df_mfccs.to_csv(csv_file_path, index=False)
    except Exception as e:
        print(f"Error processing {file_path}: {e}")

# Iterate through each input directory
for dir in input_dirs:
    for file in os.listdir(dir):
        file_path = os.path.join(dir, file)
        if file.endswith('_mfccs.npy'):
            convert_npy_to_csv(file_path, output_dir)
# Out:
# File /kaggle/input/preproccesed-dataset/audio-channel-resting/kaggle/working/preprocessed_audio_output_directory/08_mfccs.npy is empty, skipping.
# File /kaggle/input/preproccesed-dataset/audio-channel-resting/kaggle/working/preprocessed_audio_output_directory/16_mfccs.npy is empty, skipping.
# File /kaggle/input/preproccesed-dataset/audio-channel-resting/kaggle/working/preprocessed_audio_output_directory/24_mfccs.npy is empty, skipping.
# File /kaggle/input/preproccesed-dataset/audio-channel-resting/kaggle/working/preprocessed_audio_output_directory/05_mfccs.npy is empty, skipping.
# File /kaggle/input/preproccesed-dataset/audio-channel-resting/kaggle/working/preprocessed_audio_output_directory/15_mfccs.npy is empty, skipping.
# File /kaggle/input/preproccesed-dataset/audio-channel-resting/kaggle/working/preprocessed_audio_output_directory/06_mfccs.npy is empty, skipping.
# ...

# %%
import numpy as np
import pandas as pd
import os

# Directories
input_dirs = [
    '/kaggle/input/preproccesed-dataset/audio-channel-resting/kaggle/working/preprocessed_audio_output_directory',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting11/kaggle/working/preprocessed_audio_output_directory11',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting10/kaggle/working/preprocessed_audio_output_directory10',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting12/kaggle/working/preprocessed_audio_output_directory12',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting13/kaggle/working/preprocessed_audio_output_directory13',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting14/kaggle/working/preprocessed_audio_output_directory14',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting15/kaggle/working/preprocessed_audio_output_directory15',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting16/kaggle/working/preprocessed_audio_output_directory16',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting18/kaggle/working/preprocessed_audio_output_directory18',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting19/kaggle/working/preprocessed_audio_output_directory19',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting2/kaggle/working/preprocessed_audio_output_directory2',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting21/kaggle/working/preprocessed_audio_output_directory21',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting22/kaggle/working/preprocessed_audio_output_directory22',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting23/kaggle/working/preprocessed_audio_output_directory23',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting25/kaggle/working/preprocessed_audio_output_directory25',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting26/kaggle/working/preprocessed_audio_output_directory26',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting27/kaggle/working/preprocessed_audio_output_directory27',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3/kaggle/working/preprocessed_audio_output_directory3',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.1/kaggle/working/preprocessed_audio_output_directory3.1',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.10/kaggle/working/preprocessed_audio_output_directory3.10',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.14/kaggle/working/preprocessed_audio_output_directory3.14',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.15/kaggle/working/preprocessed_audio_output_directory3.15',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.16/kaggle/working/preprocessed_audio_output_directory3.16',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.17/kaggle/working/preprocessed_audio_output_directory3.17',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.2/kaggle/working/preprocessed_audio_output_directory3.2',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.4/kaggle/working/preprocessed_audio_output_directory3.4',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.5/kaggle/working/preprocessed_audio_output_directory3.5',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.6/kaggle/working/preprocessed_audio_output_directory3.6',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.7/kaggle/working/preprocessed_audio_output_directory3.7',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.8/kaggle/working/preprocessed_audio_output_directory3.8',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.9/kaggle/working/preprocessed_audio_output_directory3.9',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting4/kaggle/working/preprocessed_audio_output_directory4',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting5/kaggle/working/preprocessed_audio_output_directory5',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting6/kaggle/working/preprocessed_audio_output_directory6',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting8/kaggle/working/preprocessed_audio_output_directory8',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting9/kaggle/working/preprocessed_audio_output_directory9'
]
output_dir = '/kaggle/working/audio_csv_files'
os.makedirs(output_dir, exist_ok=True)

# Function to convert .npy files to CSV
def convert_npy_to_csv(file_path, output_dir):
    try:
        # Load .npy file with allow_pickle=True
        data = np.load(file_path, allow_pickle=True)
       
        print(data.shape)
        print(data)

        
        # Check for empty arrays
        if data.shape == ():
            print(f"File {file_path} is empty, skipping.")
            return

        # Check if data is 2D array
        if data.ndim == 2:
            df_mfccs = pd.DataFrame(data)
        # Handle 1D data
        elif data.ndim == 1:
            df_mfccs = pd.DataFrame(data.reshape(-1, 1))
        # Handle other dimensions
        else:
            print(f"Unsupported data shape {data.shape} in file {file_path}, skipping.")
            return
        
        csv_file_path = os.path.join(output_dir, os.path.basename(file_path).replace('_mfccs.npy', '.csv'))
        df_mfccs.to_csv(csv_file_path, index=False)
    except Exception as e:
        print(f"Error processing {file_path}: {e}")

# Iterate through each input directory
for dir in input_dirs:
    for file in os.listdir(dir):
        file_path = os.path.join(dir, file)
        if file.endswith('_mfccs.npy'):
            convert_npy_to_csv(file_path, output_dir)
# Out:
# ()
# None
# File /kaggle/input/preproccesed-dataset/audio-channel-resting/kaggle/working/preprocessed_audio_output_directory/08_mfccs.npy is empty, skipping.
# ()
# None
# File /kaggle/input/preproccesed-dataset/audio-channel-resting/kaggle/working/preprocessed_audio_output_directory/16_mfccs.npy is empty, skipping.
# ()
# None
# File /kaggle/input/preproccesed-dataset/audio-channel-resting/kaggle/working/preprocessed_audio_output_directory/24_mfccs.npy is empty, skipping.
# ()
# None
# File /kaggle/input/preproccesed-dataset/audio-channel-resting/kaggle/working/preprocessed_audio_output_directory/05_mfccs.npy is empty, skipping.
# ()
# None
# File /kaggle/input/preproccesed-dataset/audio-channel-resting/kaggle/working/preprocessed_audio_output_directory/15_mfccs.npy is empty, skipping.
# ()
# None
# File /kaggle/input/preproccesed-dataset/audio-channel-resting/kaggle/working/preprocessed_audio_output_directory/06_mfccs.npy is empty, skipping.
# ()
# None
# ...

# %%
import numpy as np
import pandas as pd
import os

# Directories
input_dirs = [
    '/kaggle/input/preproccesed-dataset/audio-channel-resting/kaggle/working/preprocessed_audio_output_directory',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting11/kaggle/working/preprocessed_audio_output_directory11',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting10/kaggle/working/preprocessed_audio_output_directory10',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting12/kaggle/working/preprocessed_audio_output_directory12',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting13/kaggle/working/preprocessed_audio_output_directory13',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting14/kaggle/working/preprocessed_audio_output_directory14',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting15/kaggle/working/preprocessed_audio_output_directory15',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting16/kaggle/working/preprocessed_audio_output_directory16',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting18/kaggle/working/preprocessed_audio_output_directory18',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting19/kaggle/working/preprocessed_audio_output_directory19',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting2/kaggle/working/preprocessed_audio_output_directory2',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting21/kaggle/working/preprocessed_audio_output_directory21',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting22/kaggle/working/preprocessed_audio_output_directory22',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting23/kaggle/working/preprocessed_audio_output_directory23',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting25/kaggle/working/preprocessed_audio_output_directory25',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting26/kaggle/working/preprocessed_audio_output_directory26',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting27/kaggle/working/preprocessed_audio_output_directory27',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3/kaggle/working/preprocessed_audio_output_directory3',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.1/kaggle/working/preprocessed_audio_output_directory3.1',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.10/kaggle/working/preprocessed_audio_output_directory3.10',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.14/kaggle/working/preprocessed_audio_output_directory3.14',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.15/kaggle/working/preprocessed_audio_output_directory3.15',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.16/kaggle/working/preprocessed_audio_output_directory3.16',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.17/kaggle/working/preprocessed_audio_output_directory3.17',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.2/kaggle/working/preprocessed_audio_output_directory3.2',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.4/kaggle/working/preprocessed_audio_output_directory3.4',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.5/kaggle/working/preprocessed_audio_output_directory3.5',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.6/kaggle/working/preprocessed_audio_output_directory3.6',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.7/kaggle/working/preprocessed_audio_output_directory3.7',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.8/kaggle/working/preprocessed_audio_output_directory3.8',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting3.9/kaggle/working/preprocessed_audio_output_directory3.9',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting4/kaggle/working/preprocessed_audio_output_directory4',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting5/kaggle/working/preprocessed_audio_output_directory5',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting6/kaggle/working/preprocessed_audio_output_directory6',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting8/kaggle/working/preprocessed_audio_output_directory8',
    '/kaggle/input/preproccesed-dataset/audio-channel-resting9/kaggle/working/preprocessed_audio_output_directory9'
]
output_dir = '/kaggle/working/audio_csv_files'
os.makedirs(output_dir, exist_ok=True)

# Function to convert .npy files to CSV
def convert_npy_to_csv(file_path, output_dir):
    try:
        # Load .npy file with allow_pickle=True
        data = np.load(file_path, allow_pickle=True)
        
        # Check for empty arrays
        if data.shape == ():
            print(f"File {file_path} is empty, skipping.")
            return

        # Check if data is a 1D array
        if data.ndim == 1:
            df_mfccs = pd.DataFrame(data, columns=['Value'])  # Treat as a single-column DataFrame
        else:
            print(f"Unsupported data shape {data.shape} in file {file_path}, skipping.")
            return
        
        csv_file_path = os.path.join(output_dir, os.path.basename(file_path).replace('_mfccs.npy', '.csv'))
        df_mfccs.to_csv(csv_file_path, index=False)
        print(f"Converted {file_path} to {csv_file_path}")
    except Exception as e:
        print(f"Error processing {file_path}: {e}")

# Iterate through each input directory
for dir in input_dirs:
    for file in os.listdir(dir):
        file_path = os.path.join(dir, file)
        if file.endswith('_mfccs.npy'):
            convert_npy_to_csv(file_path, output_dir)
# Out:
# File /kaggle/input/preproccesed-dataset/audio-channel-resting/kaggle/working/preprocessed_audio_output_directory/08_mfccs.npy is empty, skipping.
# File /kaggle/input/preproccesed-dataset/audio-channel-resting/kaggle/working/preprocessed_audio_output_directory/16_mfccs.npy is empty, skipping.
# File /kaggle/input/preproccesed-dataset/audio-channel-resting/kaggle/working/preprocessed_audio_output_directory/24_mfccs.npy is empty, skipping.
# File /kaggle/input/preproccesed-dataset/audio-channel-resting/kaggle/working/preprocessed_audio_output_directory/05_mfccs.npy is empty, skipping.
# File /kaggle/input/preproccesed-dataset/audio-channel-resting/kaggle/working/preprocessed_audio_output_directory/15_mfccs.npy is empty, skipping.
# File /kaggle/input/preproccesed-dataset/audio-channel-resting/kaggle/working/preprocessed_audio_output_directory/06_mfccs.npy is empty, skipping.
# ...

# %%
# !zip -r fif-to-csv.zip /kaggle/working/csv_files
# Out:
#   adding: kaggle/working/csv_files/ (stored 0%)
#   adding: kaggle/working/csv_files/02020025rest 20150713 1519..csv (deflated 54%)
#   adding: kaggle/working/csv_files/02010001_still.csv (deflated 59%)
#   adding: kaggle/working/csv_files/02020019_still.csv (deflated 96%)
#   adding: kaggle/working/csv_files/02010028rest 20160317 1538..csv (deflated 53%)
#   adding: kaggle/working/csv_files/02020023restnew 20150709 10.csv (deflated 53%)
#   adding: kaggle/working/csv_files/02010015_still.csv (deflated 61%)
#   adding: kaggle/working/csv_files/02010007_still.csv (deflated 96%)
#   adding: kaggle/working/csv_files/02030007_still.csv (deflated 61%)
#   adding: kaggle/working/csv_files/02010036_rest 20160408 1418.csv (deflated 53%)
#   adding: kaggle/working/csv_files/02010004rest 20150427 1335..csv (deflated 53%)
#   adding: kaggle/working/csv_files/02020027rest 20150713 1049..csv (deflated 54%)
#   adding: kaggle/working/csv_files/02030002_still.csv (deflated 62%)
# ...

# %%
# !zip -r audio-csv.zip /kaggle/working/audio_csv_files
# Out:
#   adding: kaggle/working/audio_csv_files/ (stored 0%)
#   adding: kaggle/working/audio_csv_files/02.csv (deflated 71%)
#   adding: kaggle/working/audio_csv_files/27.csv (deflated 60%)
#   adding: kaggle/working/audio_csv_files/11.csv (deflated 80%)
#   adding: kaggle/working/audio_csv_files/19.csv (deflated 51%)
#   adding: kaggle/working/audio_csv_files/20.csv (deflated 68%)
#   adding: kaggle/working/audio_csv_files/16.csv (deflated 73%)
#   adding: kaggle/working/audio_csv_files/13.csv (deflated 69%)
#   adding: kaggle/working/audio_csv_files/08.csv (deflated 72%)
#   adding: kaggle/working/audio_csv_files/12.csv (deflated 68%)
#   adding: kaggle/working/audio_csv_files/07.csv (deflated 78%)
#   adding: kaggle/working/audio_csv_files/06.csv (deflated 63%)
#   adding: kaggle/working/audio_csv_files/24.csv (deflated 70%)
#   adding: kaggle/working/audio_csv_files/25.csv (deflated 68%)
#   adding: kaggle/working/audio_csv_files/21.csv (deflated 72%)
# ...

# %%
# !ls
# Out:
# __notebook__.ipynb  audio-csv.zip  audio_csv_files  csv_files  fif-to-csv.zip

# %%
from IPython.display import FileLink
FileLink(r'fif-to-csv.zip')
# Out:
# /kaggle/working/fif-to-csv.zip

# %%
from IPython.display import FileLink
FileLink(r'audio-csv.zip')
# Out:
# /kaggle/working/audio-csv.zip
